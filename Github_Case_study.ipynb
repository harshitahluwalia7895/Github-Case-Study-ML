# %% [markdown]
# ###                                      An analysis of the most popular repos on Github

# %% [markdown]
# # Github

# %% [markdown]
# ### Objective of this analysis:
#
#
# ##### Learning how to read and analyse a dataset
# ##### Understanding the dominant languages used for popular GitHub projects and mapping them
# ##### Extracting the different domains of work done in these projects via the repositories tags
# ##### Deriving conclusions over the popularity of respective domains and languages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
git_df = pd.read_csv("TopStaredRepositories.csv")
git_df.head()
# Out:
#           Username         Repository Name  \
# 0     freeCodeCamp            freeCodeCamp
# 1             twbs               bootstrap
# 2  EbookFoundation  free-programming-books
# 3         facebook                   react
# 4               d3                      d3
#
#                                          Description      Last Update Date  \
# 0  The https://freeCodeCamp.com open source codeb...  2017-06-24T15:56:17Z
# 1  The most popular HTML, CSS, and JavaScript fra...  2017-06-24T15:40:21Z
# 2                 Freely available programming books  2017-06-23T01:09:34Z
# 3  A declarative, efficient, and flexible JavaScr...  2017-06-24T19:33:49Z
# 4     Bring data to life with SVG, Canvas and HTML.   2017-05-31T06:03:47Z
#
#      Language Number of Stars  \
# 0  JavaScript            290k
# 1  JavaScript            112k
# 2         NaN           87.8k
# 3  JavaScript           69.7k
# 4  JavaScript           65.7k
#
#                                                 Tags  \
# 0  nonprofits,certification,curriculum,react,node...
# 1     javascript,css,html,bootstrap,jekyll-site,scss
# 2                      education,list,books,resource
# 3                                                NaN
# 4                                      visualization
#
#                                                  Url
# 0       https://github.com/freeCodeCamp/freeCodeCamp
# 1                  https://github.com/twbs/bootstrap
# 2  https://github.com/EbookFoundation/free-progra...
# 3                  https://github.com/facebook/react
# 4                           https://github.com/d3/d3

# %%
git_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 8 columns):
# Username            980 non-null object
# Repository Name     980 non-null object
# Description         977 non-null object
# Last Update Date    980 non-null object
# Language            877 non-null object
# Number of Stars     980 non-null object
# Tags                489 non-null object
# Url                 980 non-null object
# dtypes: object(8)
# memory usage: 61.3+ KB

# %% [markdown]
# ## 1. Popular Repositories
#
# #### Determining what constitutes a popular repository by extracting the range of maximum and minimum starred repositories
#
# Converting the alphanumeric format of "Number of Stars" to numeric

# %%
git_df_max = git_df['Number of Stars'].str.contains('k').all()
git_df_max
# Out:
# True

# %%
git_df['Number of Stars']=git_df['Number of Stars'].str.replace('k','').astype(float)

# %% [markdown]
# ### 1.1 The top 5 repositories in the dataset [based on "Number of Stars"]

# %%
git_df.head()
# Out:
#           Username         Repository Name  \
# 0     freeCodeCamp            freeCodeCamp
# 1             twbs               bootstrap
# 2  EbookFoundation  free-programming-books
# 3         facebook                   react
# 4               d3                      d3
#
#                                          Description      Last Update Date  \
# 0  The https://freeCodeCamp.com open source codeb...  2017-06-24T15:56:17Z
# 1  The most popular HTML, CSS, and JavaScript fra...  2017-06-24T15:40:21Z
# 2                 Freely available programming books  2017-06-23T01:09:34Z
# 3  A declarative, efficient, and flexible JavaScr...  2017-06-24T19:33:49Z
# 4     Bring data to life with SVG, Canvas and HTML.   2017-05-31T06:03:47Z
#
#      Language  Number of Stars  \
# 0  JavaScript            290.0
# 1  JavaScript            112.0
# 2         NaN             87.8
# 3  JavaScript             69.7
# 4  JavaScript             65.7
#
#                                                 Tags  \
# 0  nonprofits,certification,curriculum,react,node...
# 1     javascript,css,html,bootstrap,jekyll-site,scss
# 2                      education,list,books,resource
# 3                                                NaN
# 4                                      visualization
#
#                                                  Url
# 0       https://github.com/freeCodeCamp/freeCodeCamp
# 1                  https://github.com/twbs/bootstrap
# 2  https://github.com/EbookFoundation/free-progra...
# 3                  https://github.com/facebook/react
# 4                           https://github.com/d3/d3

# %% [markdown]
# ### 1.2 The bottom 5 repositories in the dataset

# %%
git_df.tail()
# Out:
#               Username Repository Name  \
# 975          chrisjenx     Calligraphy
# 976           eliangcs     http-prompt
# 977  robertdavidgraham         masscan
# 978            ElemeFE         mint-ui
# 979           lhc70000            iina
#
#                                            Description      Last Update Date  \
# 975            Custom fonts in Android the easy way...  2017-06-06T19:23:22Z
# 976  HTTPie + prompt_toolkit = an interactive comma...  2017-05-11T13:27:42Z
# 977  TCP port scanner, spews SYN packets asynchrono...  2017-06-22T06:27:09Z
# 978                      Mobile UI elements for Vue.js  2017-06-22T10:02:35Z
# 979                 The modern video player for macOS.  2017-06-24T19:09:31Z
#
#     Language  Number of Stars  \
# 975     Java              6.4
# 976   Python              6.4
# 977        C              6.4
# 978      Vue              6.4
# 979    Swift              6.4
#
#                                                   Tags  \
# 975                                                NaN
# 976  python,syntax-highlighting,shell,cli,http,auto...
# 977                                                NaN
# 978         vue,mobile,component,vue-components,ui-kit
# 979                 macos,video,mpv,swift,video-player
#
#                                               Url
# 975      https://github.com/chrisjenx/Calligraphy
# 976       https://github.com/eliangcs/http-prompt
# 977  https://github.com/robertdavidgraham/masscan
# 978            https://github.com/ElemeFE/mint-ui
# 979              https://github.com/lhc70000/iina

# %% [markdown]
# ### 1.3 Statistical analysis of the repositories

# %%
git_df['Number of Stars'].describe()
# Out:
# count    980.000000
# mean      12.985714
# std       12.780092
# min        6.400000
# 25%        7.700000
# 50%        9.500000
# 75%       14.200000
# max      290.000000
# Name: Number of Stars, dtype: float64

# %% [markdown]
# #### Most popular repo- 290,000 stars
# #### Least popular repo- 6400 stars
# #### Average rating of repos- 13,000 stars

# %% [markdown]
# ### 1.3 List of all repositories with stars > 13,000

# %%
popular_repos= git_df[git_df['Number of Stars'] > 13.0]
len(popular_repos)
# Out:
# 288

# %%
popular_repos.head(8)
# Out:
#           Username         Repository Name  \
# 0     freeCodeCamp            freeCodeCamp
# 1             twbs               bootstrap
# 2  EbookFoundation  free-programming-books
# 3         facebook                   react
# 4               d3                      d3
# 5           getify        You-Dont-Know-JS
# 6       tensorflow              tensorflow
# 7     sindresorhus                 awesome
#
#                                          Description      Last Update Date  \
# 0  The https://freeCodeCamp.com open source codeb...  2017-06-24T15:56:17Z
# 1  The most popular HTML, CSS, and JavaScript fra...  2017-06-24T15:40:21Z
# 2                 Freely available programming books  2017-06-23T01:09:34Z
# 3  A declarative, efficient, and flexible JavaScr...  2017-06-24T19:33:49Z
# 4     Bring data to life with SVG, Canvas and HTML.   2017-05-31T06:03:47Z
# 5    A book series on JavaScript. @YDKJS on twitter.  2017-06-23T10:42:36Z
# 6  Computation using data flow graphs for scalabl...  2017-06-24T18:25:42Z
# 7                      Curated list of awesome lists  2017-06-24T17:26:02Z
#
#      Language  Number of Stars  \
# 0  JavaScript            290.0
# 1  JavaScript            112.0
# 2         NaN             87.8
# 3  JavaScript             69.7
# 4  JavaScript             65.7
# 5  JavaScript             62.0
# 6         C++             61.6
# 7         NaN             60.7
#
#                                                 Tags  \
# 0  nonprofits,certification,curriculum,react,node...
# 1     javascript,css,html,bootstrap,jekyll-site,scss
# 2                      education,list,books,resource
# 3                                                NaN
# 4                                      visualization
# 5  book-series,javascript,training-materials,asyn...
# 6  tensorflow,python,machine-learning,deep-neural...
# 7      lists,awesome,unicorns,resources,awesome-list
#
#                                                  Url
# 0       https://github.com/freeCodeCamp/freeCodeCamp
# 1                  https://github.com/twbs/bootstrap
# 2  https://github.com/EbookFoundation/free-progra...
# 3                  https://github.com/facebook/react
# 4                           https://github.com/d3/d3
# 5         https://github.com/getify/You-Dont-Know-JS
# 6           https://github.com/tensorflow/tensorflow
# 7            https://github.com/sindresorhus/awesome

# %%
popular_repos.tail(8)
# Out:
#           Username       Repository Name  \
# 280         jondot  awesome-react-native
# 281         apache                 spark
# 282        Thibaut               devdocs
# 283           chjj                marked
# 284           knsv               mermaid
# 285  juliangarnier                 anime
# 286     designmodo               Flat-UI
# 287  julianshapiro              velocity
#
#                                            Description      Last Update Date  \
# 280  Awesome React Native components, news, tools, ...  2017-06-23T05:34:47Z
# 281                             Mirror of Apache Spark  2017-06-24T17:07:10Z
# 282                          API Documentation Browser  2017-06-18T23:41:29Z
# 283   A markdown parser and compiler. Built for speed.  2017-06-12T01:27:25Z
# 284  Generation of diagram and flowchart from text ...  2017-06-04T07:26:58Z
# 285                        JavaScript Animation Engine  2017-06-24T15:44:51Z
# 286  Flat UI Free - Design Framework (html/css3/les...  2017-02-21T20:29:33Z
# 287                  Accelerated JavaScript animation.  2017-05-12T13:58:42Z
#
#        Language  Number of Stars  \
# 280        Ruby             13.3
# 281       Scala             13.3
# 282        Ruby             13.3
# 283        HTML             13.2
# 284  JavaScript             13.2
# 285  JavaScript             13.1
# 286         CSS             13.1
# 287  JavaScript             13.1
#
#                                                   Tags  \
# 280             react,mobile,react-native,awesome-list
# 281                                                NaN
# 282  devdocs,offline,app,documentation,docs,pwa,api...
# 283                                                NaN
# 284                                                NaN
# 285                                    anime,animation
# 286                                                NaN
# 287                                                NaN
#
#                                                 Url
# 280  https://github.com/jondot/awesome-react-native
# 281                 https://github.com/apache/spark
# 282              https://github.com/Thibaut/devdocs
# 283                  https://github.com/chjj/marked
# 284                 https://github.com/knsv/mermaid
# 285          https://github.com/juliangarnier/anime
# 286           https://github.com/designmodo/Flat-UI
# 287       https://github.com/julianshapiro/velocity

# %% [markdown]
# ### Here we see that freeCodeCamp tops the list with 290,000 stars to its repository.
# ##### The above list lists all repos that have > 13,000 stars [above average repositories]
#
#
# #### A few more observations can be derived from this list:
#    ###### 1. 5 of the most popular repos are frameworks
#    ###### 2.The third, sixth and eighth most popular repos are educational, and instructive in nature.

# %%
# classifying repositories according to the popularity
classified_repos=[]
for i in range(8,300,7):
    x = git_df[(git_df['Number of Stars'] >= i) & (git_df['Number of Stars'] <(i+7.0))]
    classified_repos.append(len(x))

# %%
indexes = []

for i in range (8000,300000, 7000):
    x = '[' + str(i) +','+ (str(i+7000)) + ')'
    indexes.append(x)

# %%
divided_repos = pd.Series(data=classified_repos, index=indexes)
divided_repos.plot(kind='bar', figsize=(15,10), color=['red'],legend=True, label='Number of repositories')

# %% [markdown]
# ## 2. Popular Languages
#
# ###### Determining the popularity of a language based on the number of repositories using it.

# %%
x=git_df['Language'].value_counts()
x.head()
# Out:
# JavaScript     338
# Java            67
# Python          63
# Ruby            44
# Objective-C     43
# Name: Language, dtype: int64

# %%
# %matplotlib inline
plt.figure()
x.plot(kind='barh',figsize=(15,10),grid=True, label='Number of repositories',legend='No of repos',title='No of repositories vs language used')

# %%
# %matplotlib inline
x[:5].plot.pie(label="Division of the top 5 languages",fontsize=10,figsize=(10,10),legend=True)

# %%
# %matplotlib inline
x[:20].plot.pie(label="Division of the top 20 languages",fontsize=10,figsize=(10,10),legend=True)

# %% [markdown]
# ## 3. Popular Domains
#
# ##### Determining the popular domains by analysing the repository tags
# ##### Removing all the null-tags fields from the dataframe

# %%
#git_df['Number of Stars']=git_df['Number of Stars'].str.replace('k','').astype(float)
nonull_df = git_df[['Tags','Number of Stars']].dropna()
tags_list = nonull_df['Tags'].str.split(',')

# %%
tags_list.head()
# Out:
# 0    [nonprofits, certification, curriculum, react,...
# 1    [javascript, css, html, bootstrap, jekyll-site...
# 2                   [education, list, books, resource]
# 4                                      [visualization]
# 5    [book-series, javascript, training-materials, ...
# Name: Tags, dtype: object

# %%
web_dev_count = 0
tags = ['javascript', 'css', 'html', 'nodejs', 'bootstrap','react', 'react-native', 'rest-api', 'rest', 'web-development','typescript','coffeescript']
for item in tags_list:
    if set(tags).intersection(item):
        web_dev_count+=1
web_dev_count
# Out:
# 171

# %%
machine_data_count=0
mach=[]
tags=['machine-learning', 'jupyter','jupter-notebook', 'tensorflow','data-science','data-analytics']
for item in tags_list:
    if set(tags).intersection(item):
        machine_data_count+=1
        mach.append(item)
machine_data_count
# Out:
# 16

# %%
mobile_dev_count=0
tags=['android','sdk','ios','swift','mobile','react','macos','windows']
for item in tags_list:
    if set(tags).intersection(item):
        mobile_dev_count+=1
mobile_dev_count
# Out:
# 99

# %%
linux_dev_count=0
linux=[]
tags=['linux','unix','bash','shell','cli','bsd']
for item in tags_list:
    if set(tags).intersection(item):
        linux_dev_count+=1
        linux.append(item)
linux_dev_count
# Out:
# 27

# %%
hardware_dev_count=0
hardware=[]
tags=['hardware','iot','smart','system','system-architecture','cloud']
for item in tags_list:
    if set(tags).intersection(item):
        hardware.append(item)
        hardware_dev_count+=1
hardware_dev_count
# Out:
# 8

# %%
domain_series=pd.Series(index=['Web Development','Data Science and Machine Learning','Mobile Development','Linux and Shell Programming','System hardware and IOT'],
                        data=[web_dev_count,machine_data_count,mobile_dev_count,linux_dev_count,hardware_dev_count])

# %%
domain_series
# Out:
# Web Development                      171
# Data Science and Machine Learning     16
# Mobile Development                    99
# Linux and Shell Programming           27
# System hardware and IOT                8
# dtype: int64

# %%
# %matplotlib inline
fig_domain=domain_series.plot(lw=2,kind='barh',figsize=(20,10),color=['green'],grid=True,title='Domain-wise repository analysis',
                              )
fig_domain.set(xlabel="Number of repositories", ylabel="Domain Name")
# Out:
# [Text(0,0.5,'Domain Name'), Text(0.5,0,'Number of repositories')]

# %% [markdown]
# ## 4. Conclusion
#
# ## Inferences from the analysis
# ##### 1.The most popular repository on GitHub is freeCodeCamp, with 290,000 stars
# ##### 2.In the top 8 repositories in the dataset, 3 are instructional and educational
# ##### 3.JavaScript is the most popularly used language, and constitutes 38.5 % of the total languages in these repositories
# ##### 4.Frameworks are the most popular type of projects across GitHub
# ##### 5.In domains, Web Development is the most popular domain of work, followed by Mobile (android, iOS, macOS, Windows) development
# ##### 6.There is no determinable correlation between the number of tags and the number of stars. The correlation coefficient is a weak 0.04646

# %% [markdown]
# ### [Extra] Popular python based projects

# %%
python_tags = git_df[git_df['Language'] == 'Python'][['Username', 'Repository Name', 'Description', 'Tags']]

# %%
python_tags
# Out:
#            Username                       Repository Name  \
# 29            vinta                        awesome-python
# 42    jakubroztocil                                httpie
# 52             nvbn                               thefuck
# 54          pallets                                 flask
# 60              rg3                            youtube-dl
# 65           django                                django
# 67         requests                              requests
# 77          ansible                               ansible
# 79     josephmisiti              awesome-machine-learning
# 104       minimaxir           big-list-of-naughty-strings
# 105          scrapy                                scrapy
# 124    scikit-learn                          scikit-learn
# 131         certbot                               certbot
# 141     shadowsocks                           shadowsocks
# 151      tensorflow                                models
# 153     donnemartin                  system-design-primer
# 170        fchollet                                 keras
# 218          XX-net                                XX-Net
# 230     ApacheInfra                              superset
# 249        Valloric                         YouCompleteMe
# 251          isocpp                     CppCoreGuidelines
# 265      tornadoweb                               tornado
# 273         soimort                               you-get
# 278          reddit                                reddit
# 291       getsentry                                sentry
# 322       songrotek  Deep-Learning-Papers-Reading-Roadmap
# 339            faif                       python-patterns
# 344         ipython                               ipython
# 354           drduh      macOS-Security-and-Privacy-Guide
# 372     adobe-fonts                       source-code-pro
# ..              ...                                   ...
# 503     donnemartin        data-science-ipython-notebooks
# 510     equinusocio                        material-theme
# 527   chrissimpkins                                  Hack
# 552           binux                              pyspider
# 562           fxsjy                                 jieba
# 571   sqlmapproject                                sqlmap
# 587          fabric                                fabric
# 603            keon                            algorithms
# 620          python                               cpython
# 646   Rochester-NRT                            RocAlphaGo
# 658        apenwarr                              sshuttle
# 668          encode                 django-rest-framework
# 684       mitmproxy                             mitmproxy
# 696          alexjc                         neural-doodle
# 716       atlassian                            localstack
# 721       saltstack                                  salt
# 742    HelloZeroNet                               ZeroNet
# 752       powerline                             powerline
# 768       nicolargo                               glances
# 824         spotify                                 luigi
# 827  home-assistant                        home-assistant
# 842          celery                                celery
# 857      getpelican                               pelican
# 861        mailpile                              Mailpile
# 876            odoo                                  odoo
# 883       getredash                                redash
# 906          alexjc                        neural-enhance
# 955          Theano                                Theano
# 967          google                           python-fire
# 976        eliangcs                           http-prompt
#
#                                            Description  \
# 29   A curated list of awesome Python frameworks, l...
# 42   Modern command line HTTP client  user-friendly...
# 52   Magnificent app which corrects your previous c...
# 54   A microframework based on Werkzeug, Jinja2 and...
# 60   Command-line program to download videos from Y...
# 65   The Web framework for perfectionists with dead...
# 67                    Python HTTP Requests for Humans
# 77   Ansible is a radically simple IT automation pl...
# 79   A curated list of awesome Machine Learning fra...
# 104  The Big List of Naughty Strings is a list of s...
# 105  Scrapy, a fast high-level web crawling & scrap...
# 124           scikit-learn: machine learning in Python
# 131  Certbot, previously the Let's Encrypt Client, ...
# 141                               Updated Jun 24, 2017
# 151                       Models built with TensorFlow
# 153  Learn how to design large-scale systems. Prep ...
# 170  Deep Learning library for Python. Runs on Tens...
# 218                                   a web proxy tool
# 230  Apache Superset (incubating) is a modern, ente...
# 249                   A code-completion engine for Vim
# 251  The C++ Core Guidelines are a set of tried-and...
# 265  Tornado is a Python web framework and asynchro...
# 273               Dumb downloader that scrapes the web
# 278                    the code that powers reddit.com
# 291  Sentry is a cross-platform crash reporting and...
# 322  Deep Learning papers reading roadmap for anyon...
# 339   A collection of design patterns/idioms in Python
# 344  Official repository for IPython itself. Other ...
# 354               A practical guide to securing macOS.
# 372  Monospaced font family for user interface and ...
# ..                                                 ...
# 503  Recently updated with 50 new notebooks! Data s...
# 510  Material Theme, the most epic theme for Sublim...
# 527                A typeface designed for source code
# 552   A Powerful Spider(Web Crawler) System in Python.
# 562                                                NaN
# 571  Automatic SQL injection and database takeover ...
# 587  Simple, Pythonic remote execution and deployment.
# 603  Minimal examples of data structures and algori...
# 620                    The Python programming language
# 646  An independent, student-led replication of Dee...
# 658  Transparent proxy server that works as a poor ...
# 668                               Web APIs for Django.
# 684  An interactive TLS-capable intercepting HTTP p...
# 696  Turn your two-bit doodles into fine artworks w...
# 716  A fully functional local AWS cloud stack. Deve...
# 721  Software to automate the management and config...
# 742  ZeroNet - Decentralized websites using Bitcoin...
# 752  Powerline is a statusline plugin for vim, and ...
# 768  Glances an Eye on your system. A top/htop alte...
# 824  Luigi is a Python module that helps you build ...
# 827   Open-source home automation platform running ...
# 842        Distributed Task Queue (development branch)
# 857  Static site generator that supports Markdown a...
# 861  A free & open modern, fast email client with u...
# 876      Odoo. Open Source Apps To Grow Your Business.
# 883  Make Your Company Data Driven. Connect to any ...
# 906   Super Resolution for images using deep learning.
# 955  Theano is a Python library that allows you to ...
# 967  Python Fire is a library for automatically gen...
# 976  HTTPie + prompt_toolkit = an interactive comma...
#
#                                                   Tags
# 29                          python,awesome,collections
# 42   python,debugging,cli,http,client,json,developm...
# 52                                        python,shell
# 54      python,flask,web-framework,wsgi,jinja,werkzeug
# 60                                                 NaN
# 65   python,django,views,framework,orm,web,apps,tem...
# 67         python,http,requests,forhumans,kennethreitz
# 77                                      python,ansible
# 79                                                 NaN
# 104                                                NaN
# 105         python,crawler,framework,scraping,crawling
# 124  python,data-science,machine-learning,statistic...
# 131  python,letsencrypt,acme-client,certificate,acm...
# 141                                                NaN
# 151                                                NaN
# 153  interview-questions,python,design,development,...
# 170  theano,tensorflow,deep-learning,data-science,m...
# 218                                 xx-net,goagent,gfw
# 230  druid,data,data-visualization,dashboards,data-...
# 249  semantic-engine,vim,code-analysis,code-completion
# 251                                                NaN
# 265                                python,asynchronous
# 273                                                NaN
# 278                           python,javascript,reddit
# 291  python,devops,django,monitoring,crash-reportin...
# 322                                      deep-learning
# 339                      python,idioms,design-patterns
# 344  python,data-science,jupyter,notebook,ipython,repl
# 354  disk-encryption,privacy,apple,macos,security,o...
# 372                            opentype-fonts,otf,font
# ..                                                 ...
# 503  python,deep-learning,kaggle,numpy,scikit-learn...
# 510  material-theme,sublime-text,material-ui,theme,...
# 527  typeface,font,developer,developer-tools,ttf,fo...
# 552                                     python,crawler
# 562                                                NaN
# 571  python,database,detection,sql-injection,pentes...
# 587                                                NaN
# 603  algorithm,python,data-structure,interview,comp...
# 620                                                NaN
# 646                                                NaN
# 658                                                NaN
# 668                                                NaN
# 684  python,tls,ssl,http,security,proxy,websocket,h...
# 696                                                NaN
# 716                                                aws
# 721  python,event-stream,zeromq,cloud-providers,eve...
# 742  bitcoin,bittorrent,torrent,web,decentralized,r...
# 752  python,vim,bash,zsh,tmux,fish,ipython,prompt,p...
# 768  python,multi-platform,terminal,web,monitoring,...
# 824  python,hadoop,scheduling,orchestration-framewo...
# 827  python,home-automation,mqtt,raspberry-pi,iot,i...
# 842                                                NaN
# 857               python,static-site-generator,pelican
# 861                                                NaN
# 876  odoo,odoo-apps,python,business,erp,apps,manage...
# 883  redshift,python,visualization,redash,mysql,big...
# 906                                                NaN
# 955                                                NaN
# 967                                                NaN
# 976  python,syntax-highlighting,shell,cli,http,auto...
#
# [63 rows x 4 columns]
